# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# /Users/robinghosh/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
train_dataset_path = 'Freshwater_Fish_Disease_Aquaculture_in_south_asia/Train'
validation_dataset_path = 'Freshwater_Fish_Disease_Aquaculture_in_south_asia/Test'

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 1747 images belonging to 7 classes.

# %%
train_datagen

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 697 images belonging to 7 classes.

# %%
validation_generator

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Bacterial Red disease
# 1 : Bacterial diseases - Aeromoniasis
# 2 : Bacterial gill disease
# 3 : Fungal diseases Saprolegniasis
# 4 : Healthy Fish
# 5 : Parasitic diseases
# 6 : Viral diseases White tail disease

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=7, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 146, 146, 128)  │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 146, 146, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 73, 73, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 73, 73, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 71, 71, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 71, 71, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 35, 35, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 35, 35, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 33, 33, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 33, 33, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,202,087 (8.40 MB)
#  Trainable params: 2,201,639 (8.40 MB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 55/55 - 31s - 560ms/step - accuracy: 0.2210 - loss: 5.1613 - val_accuracy: 0.1650 - val_loss: 4.6670 - learning_rate: 0.0010
# Epoch 2/50
# 55/55 - 30s - 551ms/step - accuracy: 0.2759 - loss: 4.7646 - val_accuracy: 0.1894 - val_loss: 2.7396 - learning_rate: 0.0010
# Epoch 3/50
# 55/55 - 30s - 537ms/step - accuracy: 0.3131 - loss: 3.7265 - val_accuracy: 0.1722 - val_loss: 3.9523 - learning_rate: 0.0010
# Epoch 4/50
# 55/55 - 29s - 528ms/step - accuracy: 0.3074 - loss: 2.9240 - val_accuracy: 0.2525 - val_loss: 2.4766 - learning_rate: 0.0010
# Epoch 5/50
# 55/55 - 29s - 530ms/step - accuracy: 0.3360 - loss: 2.3212 - val_accuracy: 0.2740 - val_loss: 2.2354 - learning_rate: 0.0010
# Epoch 6/50
# 55/55 - 29s - 536ms/step - accuracy: 0.3778 - loss: 1.8848 - val_accuracy: 0.2511 - val_loss: 2.3626 - learning_rate: 0.0010
# Epoch 7/50
# 55/55 - 29s - 532ms/step - accuracy: 0.4133 - loss: 1.6503 - val_accuracy: 0.3314 - val_loss: 1.9464 - learning_rate: 0.0010
# Epoch 8/50
# 55/55 - 30s - 537ms/step - accuracy: 0.4493 - loss: 1.5837 - val_accuracy: 0.5151 - val_loss: 1.4157 - learning_rate: 0.0010
# Epoch 9/50
# 55/55 - 30s - 544ms/step - accuracy: 0.4694 - loss: 1.4819 - val_accuracy: 0.5868 - val_loss: 1.1282 - learning_rate: 0.0010
# Epoch 10/50
# 55/55 - 30s - 552ms/step - accuracy: 0.4791 - loss: 1.4617 - val_accuracy: 0.5882 - val_loss: 1.1403 - learning_rate: 0.0010
# Epoch 11/50
# 55/55 - 30s - 547ms/step - accuracy: 0.5049 - loss: 1.3920 - val_accuracy: 0.6657 - val_loss: 1.0032 - learning_rate: 0.0010
# Epoch 12/50
# 55/55 - 30s - 543ms/step - accuracy: 0.5020 - loss: 1.3598 - val_accuracy: 0.4964 - val_loss: 1.3621 - learning_rate: 0.0010
# Epoch 13/50
# 55/55 - 30s - 545ms/step - accuracy: 0.5163 - loss: 1.3500 - val_accuracy: 0.6944 - val_loss: 0.9135 - learning_rate: 0.0010
# Epoch 14/50
# 55/55 - 30s - 538ms/step - accuracy: 0.5524 - loss: 1.2606 - val_accuracy: 0.6485 - val_loss: 1.1498 - learning_rate: 0.0010
# Epoch 15/50
# 55/55 - 30s - 544ms/step - accuracy: 0.5421 - loss: 1.2725 - val_accuracy: 0.6944 - val_loss: 0.8612 - learning_rate: 0.0010
# Epoch 16/50
# 55/55 - 32s - 580ms/step - accuracy: 0.5495 - loss: 1.2446 - val_accuracy: 0.7030 - val_loss: 0.8314 - learning_rate: 0.0010
# Epoch 17/50
# 55/55 - 30s - 553ms/step - accuracy: 0.5461 - loss: 1.2384 - val_accuracy: 0.7202 - val_loss: 0.8177 - learning_rate: 0.0010
# Epoch 18/50
# 55/55 - 30s - 551ms/step - accuracy: 0.5564 - loss: 1.1969 - val_accuracy: 0.6428 - val_loss: 0.9810 - learning_rate: 0.0010
# Epoch 19/50
# 55/55 - 30s - 551ms/step - accuracy: 0.5804 - loss: 1.1610 - val_accuracy: 0.6944 - val_loss: 1.0001 - learning_rate: 0.0010
# Epoch 20/50
# 55/55 - 30s - 538ms/step - accuracy: 0.5970 - loss: 1.1433 - val_accuracy: 0.6571 - val_loss: 0.9968 - learning_rate: 0.0010
# Epoch 21/50
# 55/55 - 30s - 550ms/step - accuracy: 0.5993 - loss: 1.1826 - val_accuracy: 0.5165 - val_loss: 1.8711 - learning_rate: 0.0010
# Epoch 22/50
# 55/55 - 31s - 555ms/step - accuracy: 0.5633 - loss: 1.1733 - val_accuracy: 0.6829 - val_loss: 0.8756 - learning_rate: 0.0010
# Epoch 23/50
# 55/55 - 30s - 554ms/step - accuracy: 0.6211 - loss: 1.0784 - val_accuracy: 0.8293 - val_loss: 0.6197 - learning_rate: 3.1623e-04
# Epoch 24/50
# 55/55 - 30s - 545ms/step - accuracy: 0.6291 - loss: 1.0085 - val_accuracy: 0.8637 - val_loss: 0.5316 - learning_rate: 3.1623e-04
# Epoch 25/50
# 55/55 - 30s - 549ms/step - accuracy: 0.6594 - loss: 0.9483 - val_accuracy: 0.7991 - val_loss: 0.6217 - learning_rate: 3.1623e-04
# Epoch 26/50
# 55/55 - 31s - 563ms/step - accuracy: 0.6754 - loss: 0.9497 - val_accuracy: 0.8149 - val_loss: 0.5641 - learning_rate: 3.1623e-04
# Epoch 27/50
# 55/55 - 29s - 535ms/step - accuracy: 0.6789 - loss: 0.8941 - val_accuracy: 0.8451 - val_loss: 0.4969 - learning_rate: 3.1623e-04
# Epoch 28/50
# 55/55 - 29s - 535ms/step - accuracy: 0.6674 - loss: 0.8958 - val_accuracy: 0.8752 - val_loss: 0.4701 - learning_rate: 3.1623e-04
# Epoch 29/50
# 55/55 - 29s - 533ms/step - accuracy: 0.6978 - loss: 0.8714 - val_accuracy: 0.8121 - val_loss: 0.5221 - learning_rate: 3.1623e-04
# Epoch 30/50
# Epoch 47/50
# 55/55 - 30s - 539ms/step - accuracy: 0.7607 - loss: 0.6910 - val_accuracy: 0.8336 - val_loss: 0.5143 - learning_rate: 3.1623e-04
# Epoch 48/50
# 55/55 - 30s - 543ms/step - accuracy: 0.7693 - loss: 0.6633 - val_accuracy: 0.9397 - val_loss: 0.2795 - learning_rate: 1.0000e-04
# Epoch 49/50
# 55/55 - 30s - 536ms/step - accuracy: 0.7613 - loss: 0.6834 - val_accuracy: 0.9397 - val_loss: 0.2608 - learning_rate: 1.0000e-04
# Epoch 50/50
# 55/55 - 33s - 598ms/step - accuracy: 0.7705 - loss: 0.6451 - val_accuracy: 0.9254 - val_loss: 0.2895 - learning_rate: 1.0000e-04

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

# learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

# ax[2].set_title('Learning Rate vs. Epochs')
# ax[2].plot(learning_rate, 'o-', label='Learning Rate')
# ax[2].set_xlabel('Epochs')
# ax[2].set_ylabel('Loss')
# ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_dataset = 'Freshwater_Fish_Disease_Aquaculture_in_south_asia/Test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 697 images belonging to 7 classes.

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9314 - loss: 0.2928

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.2917841672897339
# Test Accuracy: 0.9253945350646973

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(7, 7)  # Assuming cf_mtx is 7x7 based on your previous message

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, annot=box_labels, fmt="", cmap="YlGnBu", xticklabels=['0 : Bacterial Red disease', '1 : Bacterial diseases - Aeromoniasis', '2 : Bacterial gill disease', '3 : Fungal diseases Saprolegniasis', '4 : Healthy Fish', '5 : Parasitic diseases', '6 : Viral diseases White tail disease'], yticklabels=['0 : Bacterial Red disease', '1 : Bacterial diseases - Aeromoniasis', '2 : Bacterial gill disease', '3 : Fungal diseases Saprolegniasis', '4 : Healthy Fish', '5 : Parasitic diseases', '6 : Viral diseases White tail disease'])
  # Adjusted to use labels directly
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
from sklearn.metrics import classification_report

# Example usage
print(classification_report(y_true, y_pred, target_names=['Bacterial Red disease', 'Bacterial diseases - Aeromoniasis', 'Bacterial gill disease', 'Fungal diseases Saprolegniasis', 'Healthy Fish', 'Parasitic diseases', 'Viral diseases White tail disease']))
# Out:
#                                    precision    recall  f1-score   support
#
#             Bacterial Red disease       0.88      0.94      0.91       100
# Bacterial diseases - Aeromoniasis       0.96      0.90      0.93       100
#            Bacterial gill disease       0.95      0.93      0.94       100
#    Fungal diseases Saprolegniasis       0.96      0.93      0.94       100
#                      Healthy Fish       0.93      0.97      0.95       100
#                Parasitic diseases       0.84      0.97      0.90       100
# Viral diseases White tail disease       0.99      0.84      0.91        97
#
#                          accuracy                           0.93       697
#                         macro avg       0.93      0.93      0.93       697
#                      weighted avg       0.93      0.93      0.93       697

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))  # Adjusted figsize

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        title_text = f"True Label: {true_label} \n Pred Label: {predicted_label}"
        ax[i, j].set_title(title_text, pad=20)  # Adjusted padding for title
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout(pad=3.0)  # Adjusted padding
plt.subplots_adjust(top=0.88)  # Adjust top spacing to fit suptitle
plt.suptitle('Wrong Predictions made on test set', fontsize=20, y=1.05)  # Adjusted y for suptitle
plt.show()
